# %% [markdown]
# ## 8.5 실습과제
# ----------

# %% [markdown]
# >#### **1. 문제 정의(MD) (예제 그냥 문제 제목)**
# >Dijkstra의 최단경로 알고리즘

# %% [markdown]
# >#### **2. 알고리즘 설명(MD)  (알고리즘 설명)**
# >dist 배열에서 아직 최단거리가 확정되지 않은 최소 정점 찾는 것

# %% [markdown]
# #### **3. 손으로 푼 예제 (![이름][img]/이미지.jpg])  (책 예제 코드 이해 후 사진)**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# >#### **4. 코드 개요(입력 변수, 출력, 알고리즘 개요) (MD)**
# >##### (코드 개요 설명 1. 입력 변수 2. 출력 3. 함수설명)
# >1. 입력 변수 : shortest_path_dijkstra
# >2. 출력      &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;: path
# >3. 함수 설명 : path값으로 최단경로를 계산해서 나타낸다

# %% [markdown]
# ---------

# %% [markdown]
# #### **5. 코드(PY, C)**

# %%
def getMinVertex(dist, found):
    minv = float('inf')
    min_index = -1
    for i in range(len(dist)):
        if not found[i] and dist[i] < minv:
            minv = dist[i]
            min_index = i
    return min_index

def shortest_path_dijkstra(vtx, adj, start):
    vsize = len(vtx)
    dist = list(adj[start])
    dist[start] = 0
    path = [start] * vsize
    found = [False] * vsize
    found[start] = True
    
    for i in range(vsize - 1):  # vsize-1 steps are enough
        print("Step%2d: " % (i + 1), dist)
        u = getMinVertex(dist, found)
        found[u] = True
        
        for w in range(vsize):
            if not found[w]:
                if dist[u] + adj[u][w] < dist[w]:
                    dist[w] = dist[u] + adj[u][w]
                    path[w] = u
                    
    return path

INF = 9999

vertex = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
weight = [
    [0, 7, INF, INF, 3, 10, INF],
    [7, 0, 4, 10, 2, 6, INF],
    [INF, 4, 0, 2, INF, INF, INF],
    [INF, 10, 2, 0, 11, 9, 4],
    [3, 2, INF, 11, 0, 13, 5],
    [10, 6, INF, 9, 13, 0, INF],
    [INF, INF, INF, 4, 5, INF, 0]
]

print("Shortest Path By Dijkstra Algorithm")
start = 0
path = shortest_path_dijkstra(vertex, weight, start)

for end in range(len(vertex)):
    if end != start:
        print("[최단경로: %s->%s] %s" % (vertex[start], vertex[end], vertex[end]), end='')
        current = end
        while path[current] != start:
            print(" <- %s" % vertex[path[current]], end='')
            current = path[current]
        print(" <- %s" % vertex[start])
# Out:
# Shortest Path By Dijkstra Algorithm
# Step 1:  [0, 7, 9999, 9999, 3, 10, 9999]
# Step 2:  [0, 5, 9999, 14, 3, 10, 8]
# Step 3:  [0, 5, 9, 14, 3, 10, 8]
# Step 4:  [0, 5, 9, 12, 3, 10, 8]
# Step 5:  [0, 5, 9, 11, 3, 10, 8]
# Step 6:  [0, 5, 9, 11, 3, 10, 8]
# [최단경로: A->B] B <- E <- A
# [최단경로: A->C] C <- B <- E <- A
# [최단경로: A->D] D <- C <- B <- E <- A
# [최단경로: A->E] E <- A
# [최단경로: A->F] F <- A
# [최단경로: A->G] G <- E <- A

# %% [markdown]
# ------

# %% [markdown]
# #### **6. 테스트 코드(PY, C), 입력을 바꾸어서**

# %%
def getMinVertex(dist, found):
    minv = float('inf')
    min_index = -1
    for i in range(len(dist)):
        if not found[i] and dist[i] < minv:
            minv = dist[i]
            min_index = i
    return min_index

def shortest_path_dijkstra(vtx, adj, start):
    vsize = len(vtx)
    dist = list(adj[start])
    dist[start] = 0
    path = [start] * vsize
    found = [False] * vsize
    found[start] = True
    
    for i in range(vsize - 1):  # vsize-1 steps are enough
        print("Step%2d: " % (i + 1), dist)
        u = getMinVertex(dist, found)
        found[u] = True
        
        for w in range(vsize):
            if not found[w]:
                if dist[u] + adj[u][w] < dist[w]:
                    dist[w] = dist[u] + adj[u][w]
                    path[w] = u
                    
    return path

INF = 9999

vertex = ['A', 'B', 'C', 'D', 'E', 'F', 'G']
weight = [
    [0, 7, INF, INF, 3, 10, INF],
    [7, 0, 4, 10, 2, 6, INF],
    [INF, 4, 0, 2, INF, INF, INF],
    [INF, 10, 2, 0, 11, 9, 4],
    [3, 2, INF, 11, 0, 13, 5],
    [10, 6, INF, 9, 13, 0, INF],
    [INF, INF, INF, 4, 5, INF, 0]
]

print("Shortest Path By Dijkstra Algorithm")
start = 0
path = shortest_path_dijkstra(vertex, weight, start)

for end in range(len(vertex)):
    if end != start:
        print("[최단경로: %s->%s] %s" % (vertex[start], vertex[end], vertex[end]), end='')
        current = end
        while path[current] != start:
            print(" <- %s" % vertex[path[current]], end='')
            current = path[current]
        print(" <- %s" % vertex[start])
# Out:
# Shortest Path By Dijkstra Algorithm
# Step 1:  [0, 7, 9999, 9999, 3, 10, 9999]
# Step 2:  [0, 5, 9999, 14, 3, 10, 8]
# Step 3:  [0, 5, 9, 14, 3, 10, 8]
# Step 4:  [0, 5, 9, 12, 3, 10, 8]
# Step 5:  [0, 5, 9, 11, 3, 10, 8]
# Step 6:  [0, 5, 9, 11, 3, 10, 8]
# [최단경로: A->B] B <- E <- A
# [최단경로: A->C] C <- B <- E <- A
# [최단경로: A->D] D <- C <- B <- E <- A
# [최단경로: A->E] E <- A
# [최단경로: A->F] F <- A
# [최단경로: A->G] G <- E <- A

# %% [markdown]
# ---------

# %% [markdown]
# #### **7. 수행 결과(MD, 결과 캡춰하여 이미지로 삽입)**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------

# %% [markdown]
# >#### **8. 복잡도 분석(MD)**
# >주 반복문 내부가 O(n)이고, 알고리즘의 전체 시간 복잡도는 O(n^2)이다.

# %% [markdown]
# #### **9. 조별 협력 내용(상호지도)**
# &emsp;
