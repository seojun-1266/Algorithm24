# %% [markdown]
# ## 7.2 실습과제
# ----------

# %% [markdown]
# >#### **1. 문제 정의(MD) (예제 그냥 문제 제목)**
# >피보나치수열(테이블화 이용)

# %% [markdown]
# >#### **2. 알고리즘 설명(MD)  (알고리즘 설명)**
# >피보나치 수열을순서적으로 채워나가는 것에 초점을 맞추며 상향식으로 문제를 해결한다.

# %% [markdown]
# #### **3. 손으로 푼 예제 (![이름][img]/이미지.jpg])  (책 예제 코드 이해 후 사진)**

# %% [markdown]
# ![KakaoTalk_20240530_152846106_01.jpg](attachment:KakaoTalk_20240530_152846106_01.jpg)

# %% [markdown]
# >#### **4. 코드 개요(입력 변수, 출력, 알고리즘 개요) (MD)**
# >##### (코드 개요 설명 1. 입력 변수 2. 출력 3. 함수설명)
# >1. 입력 변수 : fib_dp_tab
# >2. 출력      &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;: 상향식으로 올라가서 피보나치 결과물이 나온다.
# >3. 함수 설명 : 피보나치의 계산은 기반상황부터 시작한다.

# %% [markdown]
# ---------

# %% [markdown]
# #### **5. 코드(PY, C)**

# %%
def fib_dp_tab(n):
    f = [None] * (n + 1)
    f[0] = 0
    f[1] = 1
    for i in range(2, n + 1):
        f[i]=f[i-1] + f[i-2]
    return f[n]
    
n = 8
print('동적계획(테이블화): Fibonacci(%d) = '% n, fib_dp_tab(n))
# Out:
# 동적계획(테이블화): Fibonacci(8) =  21

# %% [markdown]
# ------

# %% [markdown]
# #### **6. 테스트 코드(PY, C), 입력을 바꾸어서**

# %%
def fib_dp_tab(n):
    f = [None] * (n + 1)
    f[0] = 0
    f[1] = 1
    for i in range(2, n + 1):
        f[i]=f[i-1] + f[i-2]
    return f[n]
    
n = 13
print('동적계획(테이블화): Fibonacci(%d) = '% n, fib_dp_tab(n))
# Out:
# 동적계획(테이블화): Fibonacci(13) =  233

# %% [markdown]
# ---------

# %% [markdown]
# #### **7. 수행 결과(MD, 결과 캡춰하여 이미지로 삽입)**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ----------

# %% [markdown]
# >#### **8. 복잡도 분석(MD)**
# >하나의 루프를 사용하므로 명백한 O(n)이다.

# %% [markdown]
# #### **9. 조별 협력 내용(상호지도)**
# &emsp; 최민호
