# %% [markdown]
# # 문제정의
# 순환구조로 기술한 병합 정렬 알고리즘

# %% [markdown]
# # 알고리즘 설명
# 항목이 2개 이상일 경우 리스트를 2로 나눠 분할한 뒤, 리스트를 각각 정렬한뒤에 병합한다

# %% [markdown]
# # 손으로 푼 예제 이미지 사진
# ![5.1손으로 푼 예제.png](<attachment:5.1손으로 푼 예제.png>)

# %% [markdown]
# # 코드 개요
# 입력 : 정렬 전 data A,
# 출력 : 전렬 후 data
# 함수 내용 : merge_sort(A, left, right) 입력 리스트 A와 정렬하고자 하는 시작 항목과 끝 항목의 인덱스를 저장한다. 항목이 2개 이상인 경우 분할 정복을 진행하고, 함수를 다시 불러와 부분리스트를 정렬한다.

# %%
# 코드
def merge_sort(A,left,right):
    if left<right:
        mid=(left+right)//2
        merge_sort(A,left,mid)
        merge_sort(A,mid+1,right)
        merge(A,left,mid,right)

data=[7,4,5,2,1,3,9,8,6]
sorted=[0]*len(data)
print("Original : ",data)
merge_sort(data,0,len(data)-1)
print("MergeSort : ",data)
# Out:
# Original: [5, 3, 8, 4, 9, 1, 6, 2, 7]
# QuickSort: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
# 테스트 코드
def merge(A, left, mid, right):
    k = left
    i = left
    j = mid + 1
    while i <= mid and j <= right:
        if A[i] <= A[j]:
            temp[k] = A[i]
            i, k = i + 1, k + 1
        else:
            temp[k] = A[j]
            j, k = j + 1, k + 1

    if i > mid:
        temp[k:k + right - j + 1] = A[j:right + 1]
    else:
        temp[k:k + mid - i + 1] = A[i:mid + 1]

    A[left:right + 1] = temp[left:right + 1]

def merge_sort(A, left, right):
    if left < right:
        mid = (left + right) // 2
        merge_sort(A, left, mid)
        merge_sort(A, mid + 1, right)

        merge(A, left, mid, right)

#data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
data = [5, 6, 8, 4, 7, 3, 9, 1, 2]
temp = [0] * len(data)
print("Original:", data)
merge_sort(data, 0, len(data) - 1)
print("Merge Sorted:", data)
# Out:
# Original: [5, 6, 8, 4, 7, 3, 9, 1, 2]
# Merge Sorted: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 수행 결과
# ![5.1실행결과.png](attachment:5.1실행결과.png)

# %% [markdown]
# # 복잡도 분석
# log2n

# %% [markdown]
# # 협력 내용
# 홍서준 : 3, 4, 5
# 최민호 : 6, 7
# 권재훈 : 8, 9
# 이재선 : 10, 12, 13
