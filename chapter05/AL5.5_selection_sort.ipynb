# %% [markdown]
# # 문제정의
# 이진트리를 전위 순회로 방문하는 문제

# %% [markdown]
# # 알고리즘 설명
#
# 루트 노드를 먼저 방문한 후에 왼쪽 서브트리를 순회하고 오른쪽 서브트리를 순회하는 방식

# %% [markdown]
# # 손으로 푼 예제 이미지 사진
# ![5.5 손으로 푼 예제.png](<attachment:5.5 손으로 푼 예제.png>)

# %% [markdown]
# # 코드 개요
# 입력 : 트리의 각 노드
# 출력 : 트리의 높이
# 함수 내용 :
# preorder() : 이진 트리를 순회하여 노드의 값을 출력하는 gkatn

# %%
# 코드
def preorder(node):
    if node is not None:
        print(n.data, end=' ')
        preorder(n.left)
        preorder(n.right)

# %%
# 테스트 코드

class TreeNode:
    def __init__(self, key, left=None, right=None):
        self.key = key
        self.left = left
        self.right = right

def preorder(node):
    if node is not None:
        print(node.key, end=' ')  
        preorder(node.left) 
        preorder(node.right) 

d = TreeNode('D')
e = TreeNode('E')
b = TreeNode('B', d, e)
f = TreeNode('F')
c = TreeNode('C', f)
root = TreeNode('A', b, c)

print(' Pre-Order:', end=' ')
preorder(root)
print()
# Out:
#  Pre-Order: A B D E C F

# %% [markdown]
# # 수행 결과
# ![5.5실행결과.png](attachment:5.5실행결과.png)

# %% [markdown]
# # 복잡도 분석
# O(n)

# %% [markdown]
# # 협력 내용
# 홍서준 : 3, 4, 5
# 최민호 : 6, 7
# 권재훈 : 8, 9
# 이재선 : 10, 12, 13
