# %% [markdown]
# # 문제정의
# 병합정렬이 항목들을 위치에 따라 분할하는 것과는 달리 퀵정렬은 항목의 값에 따라 분할한다.

# %% [markdown]
# # 알고리즘 설명
# 주어진 리스트를 피벗을 기준으로 두 개의 서브 리스트로 분할하고 각각을 계속해서 정렬

# %% [markdown]
# # 손으로 푼 예제 이미지 사진
# ![5.3손으로 푼 예제.png](<attachment:5.3손으로 푼 예제.png>)

# %% [markdown]
# # 코드 개요
# 입력 : 정렬 전 A 리스트, left, right
# 출력 : 정렬 된 A 리스트
# 함수 내용 : quick_sort() : 계속해서 분할 및 정복

# %%
# 알고리즘 코드
def quick_sort(A, left, right) :
    if left<right:
        mid = partition(A, left, right)
        qiuck_sort(A, left, mid-1)
        quick_sort(a, mid+1, right)

# %%
# 테스트 코드
def quick_sort(A, left, right):
    if left < right:
        mid = partition(A, left, right)
        quick_sort(A, left, mid - 1)
        quick_sort(A, mid + 1, right)

def partition(A, left, right):
    pivot = A[right]
    i = left - 1
    for j in range(left, right):
        if A[j] <= pivot:
            i += 1
            A[i], A[j] = A[j], A[i]
    A[i + 1], A[right] = A[right], A[i + 1]
    return i + 1

data = [5, 3, 8, 4, 9, 1, 6, 2, 7]
print("Original: ", data)
quick_sort(data, 0, len(data)-1)
print("QuickSort: ", data)
# Out:
# Original:  [5, 3, 8, 4, 9, 1, 6, 2, 7]
# merge_sort:  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# # 수행 결과
# ![5.4실행결과.png](attachment:5.4실행결과.png)

# %% [markdown]
# # 복잡도 분석
# O(n^2)

# %% [markdown]
# # 협력 내용
# 홍서준 : 3, 4, 5
# 최민호 : 6, 7
# 권재훈 : 8, 9
# 이재선 : 10, 12, 13
