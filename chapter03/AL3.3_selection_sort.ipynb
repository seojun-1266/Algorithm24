# %% [markdown]
# # 1. 문제 정의
#
# 문자열 매칭(억지기법)

# %% [markdown]
# # 2. 알고리즘 설명
#
# 텍스트의 첫번째 문자 위치에 패턴을 놓고 비교한다. 이 과정을 패턴의 오른쪽으로 한 칸씩 옮기면서 성공한 매칭이 나타날 때까지 반복한다.

# %% [markdown]
# # 3. 손으로 푼 예제
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. 알고리즘 개요
# 함수 이름 : string_matching
# 입력 : 입력 문자열(T), 패턴 문자열(P)
# 출력 : 입력 문자열(T), 패턴 문자열(P)

# %%
# 5. 알고리즘 코드
def string_matching(T,P):
    n=len(T)
    m=len(P)
    for i in range(n-m+1):
        j=0
        while j<m and P[j] == t[i + j]:
            j = j+1
        if j==m:
            return i
    return -1

# %%
# 6. 테스트 코드

# 5. 알고리즘 코드
def string_matching(T, P):
    n = len(T)
    m = len(P)
    for i in range(n - m + 1):
        j = 0
        while j < m and P[j] == T[i + j]:
            j = j + 1
        if j == m:
            return i
    return -1

text = 'HOPF LF<G'
pattern = 'HO'
print(pattern, 'in', text, '-->', string_matching(text, pattern))
pattern = 'LF'
print(pattern, 'in', text, '-->', string_matching(text, pattern))
# Out:
# HO in HOPF LF<G --> 0
# LF in HOPF LF<G --> 5

# %% [markdown]
# # 7. 수행결과
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. 복잡도 분석
# 최선의 경우 : 패턴 문자열(P)이 입력문자열(T) 바로 앞에 존재하는 경우, 패턴 문자열의 길이(m)만큼 비교하면 되므로 O(m)이다.
#
# 최악의 경우 : 패턴 문자열(P)이 입력문자열(T)의 마지막까지 검사하는 경우, 입력문자열의 길이(n) - 패턴문자열의 길이(m)+1번 X 패턴 문자열의 길이(m) 만큼 비교해야 하므로 O(mn)이다.

# %% [markdown]
# # 9. 작성자&조협력 내용
# 이재선&
# ![image.png](attachment:image.png)
