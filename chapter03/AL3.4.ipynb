# %% [markdown]
# # 1. 문제 정의
#
# 최근접 쌍의 거리

# %% [markdown]
# # 2. 알고리즘 설명
#
# 가능한 모든 점의 pi, pj에 대해 거리를 계산하고, 가장 짧은 것을 찾는다

# %% [markdown]
# # 3. 손으로 푼 예제
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. 알고리즘 개요
# def closest_pair(p):                        #점의 전체 개수
#
#     n = len(p)                              #최근접 거리 초기화(무한대)
#
#     mindist = float("inf")
#
#     closest = None
#
#     for i in range(n-1):
#
#         for j in range(i+1, n):
#
#             dist = distance(p[i], p[j])     #유클리드 거리 계산
#
#             if dist < mindist:
#
#                 mindist = dist
#
#                 closest = (p[i], p[j])
#
#     return mindist
#
# 입력 : points = [(2, 3), (12, 30), (40, 50), (5,1), (12, 10), (3, 4)]
#
# 출력 : closest_pair(p)

# %% [markdown]
# # 5. 알고리즘 코드
# def closest_pair(p):
#     n = len(p)
#     mindist = float("inf")
#     closest = None
#     for i in range(n-1):
#         for j in range(i+1, n):
#             dist = distance(p[i], p[j])
#             if dist < mindist:
#                 mindist = dist
#                 closest = (p[i], p[j])
#     return mindist

# %%
# 6. 테스트 코드


import math

def distance(p1, p2):
    return math.sqrt((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)

def closest_pair(p):
    n = len(p)
    mindist = float("inf")
    closest = None
    for i in range(n-1):
        for j in range(i+1, n):
            dist = distance(p[i], p[j])
            if dist < mindist:
                mindist = dist
                closest = (p[i], p[j])
    return mindist, closest

points = [(2, 5), (2, 30), (46, 30), (7,1), (12, 10), (3, 4)]

min_distance, closest_pair_coords = closest_pair(points)
print("최근접 거리:", min_distance)
print("최근접 좌표:", closest_pair_coords)
# Out:
# 최근접 거리: 1.4142135623730951
# 최근접 좌표: ((2, 5), (3, 4))

# %% [markdown]
# # 7. 수행결과
# ![image.png](attachment:image.png)

# %% [markdown]
# # 8. 복잡도 분석
#
# 내부와 외부의 루프가 참으로 동작하기 때문에 O(n2)이다

# %% [markdown]
# # 9. 작성자&조협력 내용
# 권재훈&
# ![image.png](attachment:image.png)
