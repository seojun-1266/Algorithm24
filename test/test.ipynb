# %%
A = [34, 35, 43, 2, 5, 7]

def df():
    for i in range(len(A)+1):
        print(A[i])

df()
# Out:
# 34
# 35
# 43
# 2
# 5
# 7
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 7
#       4     for i in range(len(A)+1):
#       5         print(A[i])
# ----> 7 df()
#
# Cell In[18], line 5, in df()
#       3 def df():
#       4     for i in range(len(A)+1):
# ----> 5         print(A[i])
#
# IndexError: list index out of range
